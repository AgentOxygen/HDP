# %%
import xarray

xarray.open_dataset("SampleInputTemperatures.nc")
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 8, lon: 17, time: 3285)
# Coordinates:
#   * lat       (lat) float64 25.92 26.86 27.8 28.74 29.69 30.63 31.57 32.51
#   * lon       (lon) float64 255.0 256.2 257.5 258.8 ... 271.2 272.5 273.8 275.0
#   * time      (time) object 2015-01-01 00:00:00 ... 2023-12-31 00:00:00
# Data variables:
#     TREFHTMN  (time, lat, lon) float32 ...

# %%
xarray.open_dataset("SampleOutputThreshold.nc")
# Out:
# <xarray.Dataset>
# Dimensions:    (day: 365, lat: 8, lon: 17)
# Coordinates:
#   * lon        (lon) float64 255.0 256.2 257.5 258.8 ... 271.2 272.5 273.8 275.0
#   * lat        (lat) float64 25.92 26.86 27.8 28.74 29.69 30.63 31.57 32.51
#   * day        (day) int64 0 1 2 3 4 5 6 7 8 ... 357 358 359 360 361 362 363 364
# Data variables:
#     threshold  (day, lat, lon) float64 ...
# Attributes:
#     description:               90th percentile temperatures.
#     temperature dataset path:  SampleInputTemperatures.nc
